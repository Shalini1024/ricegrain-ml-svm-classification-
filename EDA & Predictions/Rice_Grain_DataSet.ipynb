# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Converting .arff file into csv format

import pandas as pd
from scipy.io import arff

# Load the ARFF file
data = arff.loadarff("C:/Users/ashwin shalini/Downloads/rice+cammeo+and+osmancik/Rice_Cammeo_Osmancik.arff")

# Convert the data to a DataFrame
df = pd.DataFrame(data[0])

# Save the DataFrame to a CSV file
df.to_csv("rice_data.csv", index=False)

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv("rice_data.csv")
df
# Out:
#          Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231.0  525.578979         229.749878          85.093788      0.928882
# 1     14656.0  494.311005         206.020065          91.730972      0.895405
# 2     14634.0  501.122009         214.106781          87.768288      0.912118
# 3     13176.0  458.342987         193.337387          87.448395      0.891861
# 4     14688.0  507.166992         211.743378          89.312454      0.906691
# ...       ...         ...                ...                ...           ...
# 3805  11441.0  415.858002         170.486771          85.756592      0.864280
# 3806  11625.0  421.390015         167.714798          89.462570      0.845850
# 3807  12437.0  442.498993         183.572922          86.801979      0.881144
# 3808   9882.0  392.296997         161.193985          78.210480      0.874406
# 3809  11434.0  404.709991         161.079269          90.868195      0.825692
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (3810, 8)

# %%
df.describe()
# Out:
#                Area    Perimeter  Major_Axis_Length  Minor_Axis_Length  \
# count   3810.000000  3810.000000        3810.000000        3810.000000
# mean   12667.727559   454.239180         188.776222          86.313750
# std     1732.367706    35.597081          17.448679           5.729817
# min     7551.000000   359.100006         145.264465          59.532406
# 25%    11370.500000   426.144753         174.353855          82.731695
# 50%    12421.500000   448.852493         185.810059          86.434647
# 75%    13950.000000   483.683746         203.550438          90.143677
# max    18913.000000   548.445984         239.010498         107.542450
#
#        Eccentricity   Convex_Area       Extent
# count   3810.000000   3810.000000  3810.000000
# mean       0.886871  12952.496850     0.661934
# std        0.020818   1776.972042     0.077239
# min        0.777233   7723.000000     0.497413
# 25%        0.872402  11626.250000     0.598862
# ...

# %%
df.isnull()
# Out:
#        Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     False      False              False              False         False
# 1     False      False              False              False         False
# 2     False      False              False              False         False
# 3     False      False              False              False         False
# 4     False      False              False              False         False
# ...     ...        ...                ...                ...           ...
# 3805  False      False              False              False         False
# 3806  False      False              False              False         False
# 3807  False      False              False              False         False
# 3808  False      False              False              False         False
# 3809  False      False              False              False         False
#
#       Convex_Area  Extent  Class
# 0           False   False  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3810 entries, 0 to 3809
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               3810 non-null   float64
#  1   Perimeter          3810 non-null   float64
#  2   Major_Axis_Length  3810 non-null   float64
#  3   Minor_Axis_Length  3810 non-null   float64
#  4   Eccentricity       3810 non-null   float64
#  5   Convex_Area        3810 non-null   float64
#  6   Extent             3810 non-null   float64
#  7   Class              3810 non-null   object
# dtypes: float64(7), object(1)
# memory usage: 238.2+ KB

# %%
df['Class'].unique()
# Out:
# array(["b'Cammeo'", "b'Osmancik'"], dtype=object)

# %%
df.count()
# Out:
# Area                 3810
# Perimeter            3810
# Major_Axis_Length    3810
# Minor_Axis_Length    3810
# Eccentricity         3810
# Convex_Area          3810
# Extent               3810
# Class                3810
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# b'Osmancik'    2180
# b'Cammeo'      1630
# Name: Class, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df['Class']
# Out:
# 0         b'Cammeo'
# 1         b'Cammeo'
# 2         b'Cammeo'
# 3         b'Cammeo'
# 4         b'Cammeo'
#            ...
# 3805    b'Osmancik'
# 3806    b'Osmancik'
# 3807    b'Osmancik'
# 3808    b'Osmancik'
# 3809    b'Osmancik'
# Name: Class, Length: 3810, dtype: object

# %% [markdown]
# Labelling the target column with numbers

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Load your dataset with 3000 records into a DataFrame, assuming it's in a file named 'your_dataset.csv'
df = pd.read_csv('rice_data.csv')

# Initialize and fit the LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(df['Class'])

# Transform the 'Class' column and store the encoded values back into the DataFrame
df['encoded_class'] = label_encoder.transform(df['Class'])

# Display the DataFrame with encoded values
print(df)
# Out:
#          Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231.0  525.578979         229.749878          85.093788      0.928882
# 1     14656.0  494.311005         206.020065          91.730972      0.895405
# 2     14634.0  501.122009         214.106781          87.768288      0.912118
# 3     13176.0  458.342987         193.337387          87.448395      0.891861
# 4     14688.0  507.166992         211.743378          89.312454      0.906691
# ...       ...         ...                ...                ...           ...
# 3805  11441.0  415.858002         170.486771          85.756592      0.864280
# 3806  11625.0  421.390015         167.714798          89.462570      0.845850
# 3807  12437.0  442.498993         183.572922          86.801979      0.881144
# 3808   9882.0  392.296997         161.193985          78.210480      0.874406
# 3809  11434.0  404.709991         161.079269          90.868195      0.825692
#
# ...

# %%
df.head()
# Out:
#       Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0  15231.0  525.578979         229.749878          85.093788      0.928882
# 1  14656.0  494.311005         206.020065          91.730972      0.895405
# 2  14634.0  501.122009         214.106781          87.768288      0.912118
# 3  13176.0  458.342987         193.337387          87.448395      0.891861
# 4  14688.0  507.166992         211.743378          89.312454      0.906691
#
#    Convex_Area    Extent      Class  encoded_class
# 0      15617.0  0.572896  b'Cammeo'              0
# 1      15072.0  0.615436  b'Cammeo'              0
# 2      14954.0  0.693259  b'Cammeo'              0
# 3      13368.0  0.640669  b'Cammeo'              0
# 4      15262.0  0.646024  b'Cammeo'              0

# %%
df.tail()
# Out:
#          Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 3805  11441.0  415.858002         170.486771          85.756592      0.864280
# 3806  11625.0  421.390015         167.714798          89.462570      0.845850
# 3807  12437.0  442.498993         183.572922          86.801979      0.881144
# 3808   9882.0  392.296997         161.193985          78.210480      0.874406
# 3809  11434.0  404.709991         161.079269          90.868195      0.825692
#
#       Convex_Area    Extent        Class  encoded_class
# 3805      11628.0  0.681012  b'Osmancik'              1
# 3806      11904.0  0.694279  b'Osmancik'              1
# 3807      12645.0  0.626739  b'Osmancik'              1
# 3808      10097.0  0.659064  b'Osmancik'              1
# 3809      11591.0  0.802949  b'Osmancik'              1

# %%
df1 = df.drop(['Class'], axis=1)
df1
# Out:
#          Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0     15231.0  525.578979         229.749878          85.093788      0.928882
# 1     14656.0  494.311005         206.020065          91.730972      0.895405
# 2     14634.0  501.122009         214.106781          87.768288      0.912118
# 3     13176.0  458.342987         193.337387          87.448395      0.891861
# 4     14688.0  507.166992         211.743378          89.312454      0.906691
# ...       ...         ...                ...                ...           ...
# 3805  11441.0  415.858002         170.486771          85.756592      0.864280
# 3806  11625.0  421.390015         167.714798          89.462570      0.845850
# 3807  12437.0  442.498993         183.572922          86.801979      0.881144
# 3808   9882.0  392.296997         161.193985          78.210480      0.874406
# 3809  11434.0  404.709991         161.079269          90.868195      0.825692
#
# ...

# %% [markdown]
# # Data Visualizations

# %%
Osmancik_df = df1[df1['encoded_class']==1]
Cammeo_df = df1[df1['encoded_class']==0]

axes = Osmancik_df.plot(kind="scatter", x='Area', y='Eccentricity' , color="orange" , label="Osmancik")
Cammeo_df.plot(kind="scatter" , x='Area', y='Eccentricity' , color="blue" , label="Cammeo" , ax=axes)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Eccentricity'>

# %%
sns.boxplot(x='encoded_class', y='Area', data=df1)
plt.show()

# %%
sns.barplot(x='encoded_class', y='Area', data=df1, estimator=sum)
plt.show()

# %%
sns.violinplot(x='encoded_class', y='Major_Axis_Length', data=df1)
plt.show()

# %%
sns.pairplot(df1, hue='encoded_class')
plt.show()

# %%
df1.dtypes
# Out:
# Area                 float64
# Perimeter            float64
# Major_Axis_Length    float64
# Minor_Axis_Length    float64
# Eccentricity         float64
# Convex_Area          float64
# Extent               float64
# encoded_class          int32
# dtype: object

# %%
df1.columns
# Out:
# Index(['Area', 'Perimeter', 'Major_Axis_Length', 'Minor_Axis_Length',
#        'Eccentricity', 'Convex_Area', 'Extent', 'encoded_class'],
#       dtype='object')

# %%
feature_df = df1[['Area', 'Perimeter', 'Major_Axis_Length', 'Minor_Axis_Length',
       'Eccentricity', 'Convex_Area', 'Extent']]
X = np.asarray(feature_df)
X
# Out:
# array([[1.52310000e+04, 5.25578979e+02, 2.29749878e+02, ...,
#         9.28882003e-01, 1.56170000e+04, 5.72895527e-01],
#        [1.46560000e+04, 4.94311005e+02, 2.06020065e+02, ...,
#         8.95404994e-01, 1.50720000e+04, 6.15436316e-01],
#        [1.46340000e+04, 5.01122009e+02, 2.14106781e+02, ...,
#         9.12118077e-01, 1.49540000e+04, 6.93258822e-01],
#        ...,
#        [1.24370000e+04, 4.42498993e+02, 1.83572922e+02, ...,
#         8.81144345e-01, 1.26450000e+04, 6.26738548e-01],
#        [9.88200000e+03, 3.92296997e+02, 1.61193985e+02, ...,
#         8.74406099e-01, 1.00970000e+04, 6.59063637e-01],
#        [1.14340000e+04, 4.04709991e+02, 1.61079269e+02, ...,
#         8.25692177e-01, 1.15910000e+04, 8.02949429e-01]])

# %%
y = np.asarray(df1['encoded_class'])
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train , X_test ,y_train , y_test = train_test_split(X , y , test_size=0.2, random_state=5)

# %%
X_train.shape
# Out:
# (3048, 7)

# %%
X_test.shape
# Out:
# (762, 7)

# %% [markdown]
# # Training a model (SVM with Scikit learn)

# %%
from sklearn import svm

classifier = svm.SVC(kernel='linear' , gamma = 'auto' , C = 2)
classifier.fit(X_train, y_train)

y_predict = classifier.predict(X_test)

# %% [markdown]
# # Evaluating the results

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       321
#            1       0.93      0.94      0.93       441
#
#     accuracy                           0.92       762
#    macro avg       0.92      0.92      0.92       762
# weighted avg       0.92      0.92      0.92       762
